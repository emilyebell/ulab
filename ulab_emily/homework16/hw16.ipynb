# %% [markdown]
# # HW 16 - Animation
# ULAB - Physics and Astronomy Division \
# Due **Sunday, March 16th, 2025 at 11:59pm** on Gradescope
#
# **Make sure to work on this notebook in DataHub!**
#
# # 1) Recap of lecture
# **Copy and paste** your code from lecture for the neural network with the **default** settings (i.e. before we improved the model). Make sure to also import the `data.py` file.

# %%
# Your code here

import torch
import numpy as np 
import data
import matplotlib.pyplot as plt

plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), #input x,y=2
    torch.nn.Sigmoid(),
    torch.nn.Linear(50, 1)
) #output z=1

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.0157110691070557
# Iteration 100, Loss: 0.9529028534889221
# Iteration 200, Loss: 0.8639794588088989
# Iteration 300, Loss: 0.7244641780853271
# Iteration 400, Loss: 0.588395357131958
# Iteration 500, Loss: 0.4745124578475952
# Iteration 600, Loss: 0.37543633580207825
# Iteration 700, Loss: 0.30020490288734436
# Iteration 800, Loss: 0.2495308816432953
# Iteration 900, Loss: 0.22000746428966522

# %% [markdown]
# What is the difference between artificial intelligence, machine learning and deep learning?

# %%
# Your comment here 
# artificial intelligence is the broad field of intelligent systems, machine learning is a subset that learns from data, and deep learning is a deeper ML approach using neural networks.

# %% [markdown]
# What is a neural network?

# %%
# Your comment here
# a neural network is a type of ML inspired by the human brain that learns patterns to make predictions or decisions.

# %% [markdown]
# In lecture, we used `torch.nn.Linear(2, 50)`. What do the numbers `2` and `50` represent?

# %%
# Your comment here
# 2 represents the number of input features and 50 represents the number of output features.

# %% [markdown]
# What does the activation function do?

# %%
# Your comment here
# The activation function will introduce non-linearity to the model, helping it to make better predictions.

# %% [markdown]
# What is a loss function? Why do we need one?

# %%
# A loss function measures how far a model's predictions are from the actual values, this helps to guide the optimization process and keep it from "losing" too much.

# %% [markdown]
# Why do we call `optimizer.zero_grad()` before calling `loss.backward()`?

# %%
# Your comment here
# We call optimizer.zero_grad() before loss.backward() to reset the gradients of all model parameters to zero.

# %% [markdown]
# # 2) Modifying the Neural Network
# What line do you need to modify to use **30 neurons** instead of **50**? Don't change anything else. Give the original and then modified line.

# %%
# Your code here
# Original: torch.nn.Linear(2, 50)
# Modified: torch.nn.Linear(2, 30)

# %% [markdown]
# With your default code above, run your model with **30 neurons**. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# Your comment here
plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

model = torch.nn.Sequential(
    torch.nn.Linear(2, 30), #input x,y=2
    torch.nn.Sigmoid(),
    torch.nn.Linear(30, 1)
) #output z=1

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.0101869106292725
# Iteration 100, Loss: 0.9589611887931824
# Iteration 200, Loss: 0.8978143334388733
# Iteration 300, Loss: 0.782808244228363
# Iteration 400, Loss: 0.6506057381629944
# Iteration 500, Loss: 0.5411543846130371
# Iteration 600, Loss: 0.4647941589355469
# Iteration 700, Loss: 0.41068682074546814
# Iteration 800, Loss: 0.3709905743598938
# Iteration 900, Loss: 0.34405508637428284

# %%
# The loss when using 30 neurons is 0.34, but with 50 neurons is 0.22 therefore the model was better with 50.

# %% [markdown]
# Return to **50 neurons**. Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.ReLU`. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# Your comment here
# Your comment here
plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), #input x,y=2
    torch.nn.ReLU(),
    torch.nn.Linear(50, 1)
) #output z=1

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.7668535709381104
# Iteration 100, Loss: 0.8886992335319519
# Iteration 200, Loss: 0.8031013011932373
# Iteration 300, Loss: 0.696587324142456
# Iteration 400, Loss: 0.5966313481330872
# Iteration 500, Loss: 0.524129331111908
# Iteration 600, Loss: 0.4661129415035248
# Iteration 700, Loss: 0.42296454310417175
# Iteration 800, Loss: 0.39146268367767334
# Iteration 900, Loss: 0.3723927438259125

# %%
# The loss using ReLU is 0.37 which is greater than that of our model in lecture.

# %% [markdown]
# Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.Tanh`? Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# Your comment here
# Your comment here
# Your comment here
plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), #input x,y=2
    torch.nn.Tanh(),
    torch.nn.Linear(50, 1)
) #output z=1

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.02693510055542
# Iteration 100, Loss: 0.7758163809776306
# Iteration 200, Loss: 0.5436835885047913
# Iteration 300, Loss: 0.38341325521469116
# Iteration 400, Loss: 0.30718594789505005
# Iteration 500, Loss: 0.25823864340782166
# Iteration 600, Loss: 0.22487829625606537
# Iteration 700, Loss: 0.19642658531665802
# Iteration 800, Loss: 0.17290106415748596
# Iteration 900, Loss: 0.15391382575035095

# %%
# Here, the loss of 0.15 is actually better than what we had in lecture.

# %% [markdown]
# What is the difference between `torch.nn.Sigmoid()`, `torch.nn.ReLU` and `torch.nn.Tanh`?

# %%
# Your comment here 
# These represent different activation functions that introduce non-linearity in different ways.

# %% [markdown]
# Return to `torch.nn.Sigmoid()`. Change your learning rate from `1e-3` to `1e-2` in your optimizer. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# Your comment here
plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), #input x,y=2
    torch.nn.Sigmoid(),
    torch.nn.Linear(50, 1)
) #output z=1

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.132372260093689
# Iteration 100, Loss: 0.4409724175930023
# Iteration 200, Loss: 0.29546278715133667
# Iteration 300, Loss: 0.1705484688282013
# Iteration 400, Loss: 0.12394257634878159
# Iteration 500, Loss: 0.10123561322689056
# Iteration 600, Loss: 0.08857973664999008
# Iteration 700, Loss: 0.08030515164136887
# Iteration 800, Loss: 0.06801345944404602
# Iteration 900, Loss: 0.0533352829515934

# %%
# This one ends up with a loss of 0.05 which is dramatically better than the loss from our code from lecture.

# %% [markdown]
# Modify your model to have **two hidden layers** instead of one. Give that code here.

# %%
# Your code here
plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

model = torch.nn.Sequential(
    torch.nn.Linear(2, 30), 
    torch.nn.Sigmoid(),
    torch.nn.Linear(30, 20), 
    torch.nn.Sigmoid(),        
    torch.nn.Linear(20, 1)  
)

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.0084900856018066
# Iteration 100, Loss: 0.3650909662246704
# Iteration 200, Loss: 0.28334057331085205
# Iteration 300, Loss: 0.226407989859581
# Iteration 400, Loss: 0.1679861843585968
# Iteration 500, Loss: 0.1279127299785614
# Iteration 600, Loss: 0.09895080327987671
# Iteration 700, Loss: 0.08517120778560638
# Iteration 800, Loss: 0.07701271772384644
# Iteration 900, Loss: 0.07148946821689606

# %% [markdown]
# # 3) More Advanced
# Create a new file called `new_data.py`, make a new "hidden" function and add noise/ obscure the data (e.g. like what is done in `data.py` from lecture). Import that file here.

# %%
# Your code here
import new_data

# %% [markdown]
# Define a new model and train it **poorly** in the cell below.

# %%
# Your code here
plt.figure(figsize=(3,3))
plt.scatter(data.x_values, data.y_values, c=data.color_values)
plt.show()

poor_model = torch.nn.Sequential(
    torch.nn.Linear(2, 5),
    torch.nn.Sigmoid(),
    torch.nn.Linear(5, 1)
)

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(poor_model.parameters(), lr=1e-5)

for t in range(50):
    y_pred = poor_model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 10 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
output = poor_model(grid).detach()
plt.imshow(output, extent=(-10,10,-10,10))
plt.show()
# Out:
# Iteration 0, Loss: 1.1662782430648804
# Iteration 10, Loss: 1.1660053730010986
# Iteration 20, Loss: 1.1657334566116333
# Iteration 30, Loss: 1.1654614210128784
# Iteration 40, Loss: 1.1651901006698608

# %% [markdown]
# Improve your model and train it **well** in the cell below. (You can add more neurons, iterations, etc).

# %% [markdown]
# Make foure subplots (two rows, two columns).
# - (TOP LEFT) Show what the "hidden pattern" is supposed to be.
# - (TOP RIGHT) Show that your "data" is.
# - (BOTTOM LEFT) Show your model's prediction when you trained it poorly.
# - (BOTTOM RIGHT) Show your model's prediction when you trained it well.

# %%
# Your code here

good_model = torch.nn.Sequential(
    torch.nn.Linear(2, 50),
    torch.nn.ReLU(),
    torch.nn.Linear(50, 30),
    torch.nn.ReLU(),
    torch.nn.Linear(30, 1)
)

poor_model = torch.nn.Sequential(
    torch.nn.Linear(2, 5),  
    torch.nn.Sigmoid(),
    torch.nn.Linear(5, 1)
)

loss_fn = torch.nn.MSELoss()
optimizer_well = torch.optim.Adam(good_model.parameters(), lr=1e-3)
optimizer_poor = torch.optim.Adam(poor_model.parameters(), lr=1e-5)

for t in range(1000):
    y_pred = good_model(torch.tensor(new_data.x, dtype=torch.float32))
    loss = loss_fn(y_pred, torch.tensor(new_data.y, dtype=torch.float32))
    optimizer_well.zero_grad()
    loss.backward()
    optimizer_well.step()

for t in range(50):  # Too few iterations
    y_pred = poor_model(torch.tensor(new_data.x, dtype=torch.float32))
    loss = loss_fn(y_pred, torch.tensor(new_data.y, dtype=torch.float32))
    optimizer_poor.zero_grad()
    loss.backward()
    optimizer_poor.step()

new_x = torch.linspace(-10, 10, 100)
grid_x, grid_y = torch.meshgrid(new_x, new_x, indexing="ij")
grid = torch.stack((grid_x, grid_y), dim=-1).reshape(-1, 2)
output_well = good_model(grid).detach().numpy().reshape(100, 100)
output_poor = poor_model(grid).detach().numpy().reshape(100, 100)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# TOP LEFT
axs[0, 0].imshow(new_data.pattern, extent=(-10, 10, -10, 10))
axs[0, 0].set_title("Hidden Pattern")
# TOP RIGHT
axs[0, 1].scatter(new_data.x_values, new_data.y_values, c=new_data.color_values)
axs[0, 1].set_title("Noisy Data")
# BOTTOM LEFT
axs[1, 0].imshow(output_poor, extent=(-10, 10, -10, 10))
axs[1, 0].set_title("Poor Model Prediction")
# BOTTOM RIGHT
axs[1, 1].imshow(output_well, extent=(-10, 10, -10, 10))
axs[1, 1].set_title("Well-Trained Model Prediction")

plt.show()
# Out:
# /var/folders/t4/tsr_bxjd4yx7wfsg954svp6w0000gp/T/ipykernel_8621/1297740877.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = good_model(torch.tensor(new_data.x, dtype=torch.float32))
# /var/folders/t4/tsr_bxjd4yx7wfsg954svp6w0000gp/T/ipykernel_8621/1297740877.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss = loss_fn(y_pred, torch.tensor(new_data.y, dtype=torch.float32))
# /var/folders/t4/tsr_bxjd4yx7wfsg954svp6w0000gp/T/ipykernel_8621/1297740877.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = poor_model(torch.tensor(new_data.x, dtype=torch.float32))
# /var/folders/t4/tsr_bxjd4yx7wfsg954svp6w0000gp/T/ipykernel_8621/1297740877.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss = loss_fn(y_pred, torch.tensor(new_data.y, dtype=torch.float32))

# %% [markdown]
# # 4) Challenge
# Find some data online and build a neural network around it. Make sure to also answer these questions:
# - Where did you find your data?
# - How well does your model match your data?

# %%
# Your code here

# %% [markdown]
# Once you are done, make sure to:
# - Download this notebook and all releveant files (`new_data.py`, stuff from question 4, etc) from datahub.
# - Move it to your **remote repository**.
# - Upload to Gradescope!
